# %% [markdown]
# # Download the UCI Adults dataset from the Database
# Find two examples in the course content in Blackboard
# Database Details:
# user='new_haven_ds_read'
# password='new_haven_ds_secret_99'
# host='nhds.cwroivw0q1rc.us-east-1.rds.amazonaws.com'
# database='nhds'
#
#
#  SQL: sql = 'select * from nhds.uci_adults'

# %%
import postgresql
import pandas
import pickle

# %%
db = postgresql.open("pq://new_haven_ds_read:new_haven_ds_secret_99@nhds.cwroivw0q1rc.us-east-1.rds.amazonaws.com/nhds")
sql = 'select * from nhds.uci_adults'
ps = db.prepare(sql)
res = ps()

# %% [markdown]
# ### 1. How many rows are in the result set?

# %%
len(res)
# Out:
# 32561

# %% [markdown]
# ### 2. Create a DataFrame from the dataset

# %%
df = pandas.DataFrame(res, columns=ps.column_names)
df
# Out:
#        age          workclass  fnlwgt    education  educational_num  \
# 0       39          State-gov   77516    Bachelors               13
# 1       50   Self-emp-not-inc   83311    Bachelors               13
# 2       38            Private  215646      HS-grad                9
# 3       53            Private  234721         11th                7
# 4       28            Private  338409    Bachelors               13
# ...    ...                ...     ...          ...              ...
# 32556   27            Private  257302   Assoc-acdm               12
# 32557   40            Private  154374      HS-grad                9
# 32558   58            Private  151910      HS-grad                9
# 32559   22            Private  201490      HS-grad                9
# 32560   52       Self-emp-inc  287927      HS-grad                9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ### 3. How many columns are in the DataFrame?

# %%
print(df.shape)
print('This shows that there are 16 columns')
# Out:
# (32561, 16)
# This shows that there are 16 columns

# %% [markdown]
# ### 4. What percentage of records show an individual making more than $50k/yr ?

# %%
a = df.income
percent = a.value_counts(normalize = True)
print(percent)
print('We can see that percentage of records for an individual making more than $50k/yr is 0.24081')
# Out:
#  <=50K    0.75919
#  >50K     0.24081
# Name: income, dtype: float64
# We can see that percentage of records for an individual making more than $50k/yr is 0.24081

# %% [markdown]
# ### 5. Create a new column with an integer value representing income bucket (should be one of two values showing above/below 50k)

# %%
# Create the dictionary 
income_dictionary ={'<=50K' : '1', '>50K' : '2'} 
  
# Add a new column named 'Price' 
df['income_index'] = df['income'].map(income_dictionary) 
  
# Print the DataFrame 
df
# Out:
#        age          workclass  fnlwgt    education  educational_num  \
# 0       39          State-gov   77516    Bachelors               13
# 1       50   Self-emp-not-inc   83311    Bachelors               13
# 2       38            Private  215646      HS-grad                9
# 3       53            Private  234721         11th                7
# 4       28            Private  338409    Bachelors               13
# ...    ...                ...     ...          ...              ...
# 32556   27            Private  257302   Assoc-acdm               12
# 32557   40            Private  154374      HS-grad                9
# 32558   58            Private  151910      HS-grad                9
# 32559   22            Private  201490      HS-grad                9
# 32560   52       Self-emp-inc  287927      HS-grad                9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %% [markdown]
# ### 6. Pickle the dataset.  How much disk space does the pickled object use?

# %%
df.to_pickle('df.pkl')

# %%
del(df)
df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-f19487050912> in <module>
#       1 del(df)
# ----> 2 df
#
# NameError: name 'df' is not defined

# %%
df = pandas.read_pickle('df.pkl')
df
# Out:
#        age          workclass  fnlwgt    education  educational_num  \
# 0       39          State-gov   77516    Bachelors               13
# 1       50   Self-emp-not-inc   83311    Bachelors               13
# 2       38            Private  215646      HS-grad                9
# 3       53            Private  234721         11th                7
# 4       28            Private  338409    Bachelors               13
# ...    ...                ...     ...          ...              ...
# 32556   27            Private  257302   Assoc-acdm               12
# 32557   40            Private  154374      HS-grad                9
# 32558   58            Private  151910      HS-grad                9
# 32559   22            Private  201490      HS-grad                9
# 32560   52       Self-emp-inc  287927      HS-grad                9
#
#             marital_status          occupation    relationship    race  \
# 0            Never-married        Adm-clerical   Not-in-family   White
# ...

# %%
#How much disk space does the pickled object use?
df.info(verbose=False, memory_usage="deep")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Columns: 17 entries, age to income_index
# dtypes: int64(7), object(10)
# memory usage: 21.4 MB

# %% [markdown]
# ### 7. How many distinct values exist in the dataset for occupation ?

# %%
df.occupation.nunique()
# Out:
# 15

# %% [markdown]
# ### 8. Explain why we practiced using the python pickle function in class.  Why would this be useful when working with large datasets?

# %%
'This dataset only has 32561 rows. The Python pickle does not make much difference. But if there were millions of records, Jupyter Notebook would have to read the data from UCI website and it would be too much memory size. In this case, using the Python Pickle would make sure that Jupyter Notebook would not need to go back the UCI website again to read these million rows. This is when this function is extremely useful'
# Out:
# 'This dataset only has 32561 rows. The Python pickle does not make much difference. But if there were millions of records, Jupyter Notebook would have to read the data from UCI website and it would be too much memory size. In this case, using the Python Pickle would make sure that Jupyter Notebook would not need to go back the UCI website again to read these million rows. This is when this function is extremely useful'
